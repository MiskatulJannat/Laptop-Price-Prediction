# %% [markdown]
# # Laptop Price Prediction

# %% [markdown]
# ## Assignment
# Your task is to define and train a machine learning model for predicting the price of a laptop (`buynow_price` column in the dataset) based on its attributes. When testing and comparing your models, aim to minimize the `RMSE` measure.

# %% [markdown]
# ## Data Description
# The dataset has already been randomly divided into the training, validation and test sets. It is stored in 3 files: `train_dataset.json, val_dataset.json and test_dataset.json` respectively. Each file is JSON saved in `orient=’columns’` format.
#
# Example how to load the data:
#
# ```python
# import pandas as pd
# dataset = pd.read_json("public-dataset.json")
# dataset.columns
# Index(['buynow_price', 'graphic card type', 'communications', 'resolution (px)', 'CPU cores', 'RAM size', 'operating system', 'drive type', 'input devices', 'multimedia', 'RAM type', 'CPU clock speed (GHz)', 'CPU model', 'state', 'drive memory size (GB)', 'warranty', 'screen size'], dtype='object')
# ```

# %% [markdown]
# # Solution

# %% [markdown]
# ## Data Loading

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Data Science Bootcamp/Laptop Price Prediction/datasets/train_dataset.json', orient='columns')
val_df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Data Science Bootcamp/Laptop Price Prediction/datasets/val_dataset.json', orient='columns')
test_df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Data Science Bootcamp/Laptop Price Prediction/datasets/test_dataset.json', orient='columns')

# %%
df = pd.concat([train_df, val_df, test_df], axis=0)
df.head()
# Out:
#          graphic card type                               communications  \
# 7233    dedicated graphics            [bluetooth, lan 10/100/1000 mbps]
# 5845    dedicated graphics          [wi-fi, bluetooth, lan 10/100 mbps]
# 10303                 None  [bluetooth, nfc (near field communication)]
# 10423                 None                                         None
# 5897   integrated graphics                           [wi-fi, bluetooth]
#
#       resolution (px) CPU cores RAM size   operating system drive type  \
# 7233      1920 x 1080         4    32 gb        [no system]  ssd + hdd
# 5845       1366 x 768         4     8 gb  [windows 10 home]        ssd
# 10303     1920 x 1080         2     8 gb  [windows 10 home]        hdd
# 10423            None         2     None               None       None
# 5897      2560 x 1440         4     8 gb  [windows 10 home]        ssd
#
#                                            input devices  \
# 7233   [keyboard, touchpad, illuminated keyboard, num...
# 5845              [keyboard, touchpad, numeric keyboard]
# 10303                                               None
# 10423                                               None
# 5897          [keyboard, touchpad, illuminated keyboard]
#
#                                            multimedia RAM type  \
# 7233   [SD card reader, camera, speakers, microphone]     ddr4
# 5845   [SD card reader, camera, speakers, microphone]     ddr3
# 10303                                [SD card reader]     ddr4
# 10423                                            None     None
# 5897   [SD card reader, camera, speakers, microphone]     ddr4
#
#        CPU clock speed (GHz)      CPU model state  drive memory size (GB)  \
# 7233                     2.6  intel core i7   new                  1250.0
# 5845                     2.4  intel core i7   new                   256.0
# 10303                    1.6  intel core i7   new                  1000.0
# 10423                    NaN           None   new                     NaN
# 5897                     1.2      other CPU   new                   256.0
#
#                 warranty  screen size  buynow_price
# 7233   producer warranty  17" - 17.9"        4999.0
# 5845     seller warranty  15" - 15.9"        2649.0
# 10303  producer warranty  15" - 15.9"        3399.0
# 10423  producer warranty         None        1599.0
# 5897   producer warranty  12" - 12.9"        4499.0

# %%
df.dtypes
# Out:
# graphic card type          object
# communications             object
# resolution (px)            object
# CPU cores                  object
# RAM size                   object
# operating system           object
# drive type                 object
# input devices              object
# multimedia                 object
# RAM type                   object
# CPU clock speed (GHz)     float64
# CPU model                  object
# state                      object
# drive memory size (GB)    float64
# warranty                   object
# screen size                object
# buynow_price              float64
# dtype: object

# %%
df.shape
# Out:
# (7853, 17)

# %% [markdown]
# ## Data Exploration & Preprocessing

# %%
# feature wise unique value exploration
for col in df.columns.to_list():
    if type(df[col][0]) != list:
        print(f"Unique values {col}: {df[col].unique()}")
        print("--------------------------------------------------")
        print()
# Out:
# Unique values graphic card type: ['dedicated graphics' None 'integrated graphics']
# --------------------------------------------------
#
# Unique values resolution (px): ['1920 x 1080' '1366 x 768' None '2560 x 1440' '1600 x 900' '3840 x 2160'
#  'other' '1920 x 1280' '1280 x 800' '3200 x 1800' '2880 x 1620'
#  '2160 x 1440' '1920 x 1200' '2560 x 1600']
# --------------------------------------------------
#
# Unique values CPU cores: ['4' '2' 'not applicable' '3' '1' '8' '6']
# --------------------------------------------------
#
# Unique values RAM size: ['32 gb' '8 gb' None '12 gb' '4 gb' '16 gb' '2 gb' '20 gb' '6 gb' '64 gb'
#  '256 mb' '24 gb']
# --------------------------------------------------
#
# Unique values drive type: ['ssd + hdd' 'ssd' 'hdd' None 'emmc' 'hybrid']
# --------------------------------------------------
#
# Unique values RAM type: ['ddr4' 'ddr3' None 'ddr3l']
# --------------------------------------------------
#
# Unique values CPU clock speed (GHz): [2.6  2.4  1.6   nan 1.2  2.   2.5  2.8  1.9  1.1  2.3  2.24 1.8  3.
#  1.7  2.1  2.7  1.33 2.2  3.9  2.16 2.9  1.83 0.9  1.   1.44 1.58 1.35
#  3.1  0.8  3.5  1.3  1.5  1.86 3.3  1.15 1.68 1.4  2.66 2.13 1.66 1.46
#  2.56 3.8  3.6  0.  ]
# --------------------------------------------------
#
# Unique values CPU model: ['intel core i7' None 'other CPU' 'intel core i3' 'intel core i5'
#  'intel celeron dual-core' 'intel pentium 4' 'intel celeron quad core '
#  'amd a6' 'intel celeron ' 'intel pentium dual-core' 'amd a12' 'amd a8'
#  'intel pentium quad-core ' 'intel core m' 'amd a4' 'intel celeron m'
#  'amd a10' 'amd e1']
# --------------------------------------------------
#
# Unique values state: ['new']
# --------------------------------------------------
#
# Unique values drive memory size (GB): [1.250e+03 2.560e+02 1.000e+03       nan 5.000e+02 1.128e+03 1.240e+03
#  1.200e+02 1.256e+03 4.800e+02 2.500e+02 1.280e+02 2.400e+02 3.200e+01
#  9.600e+02 6.400e+01 1.000e+00 1.120e+03 2.128e+03 6.800e+01 5.120e+02
#  1.512e+03 1.500e+03 2.000e+03 1.628e+03 2.256e+03 1.800e+02 2.512e+03
#  1.024e+03 2.500e+03 1.756e+03 6.280e+02 5.080e+02 1.520e+02 3.200e+02
#  1.012e+03 7.560e+02 1.600e+02 2.480e+03 4.880e+02 8.000e+00 2.048e+03
#  0.000e+00 1.000e+02 1.008e+03 9.900e+02 2.120e+03 2.480e+02 7.500e+02
#  6.080e+02 4.960e+02 2.960e+03 1.920e+02 1.525e+03 3.680e+02 3.840e+02
#  7.400e+02 5.250e+02 1.480e+03 5.160e+02 3.640e+02 2.720e+02 1.280e+03
#  1.728e+03 1.726e+03 5.240e+02 7.680e+02 2.250e+03 1.000e+04 6.000e+01
#  1.275e+03 2.750e+02 9.800e+02]
# --------------------------------------------------
#
# Unique values warranty: ['producer warranty' 'seller warranty' 'no warranty']
# --------------------------------------------------
#
# Unique values screen size: ['17" - 17.9"' '15" - 15.9"' None '12" - 12.9"' '14" - 14.9"'
#  '13" - 13.9"' '11.9" and less']
# --------------------------------------------------
#
# Unique values buynow_price: [4999.   2649.   3399.   ... 2925.36 8678.   4722.  ]
# --------------------------------------------------

# %%
df.columns.to_list()
# Out:
# ['graphic card type',
#  'communications',
#  'resolution (px)',
#  'CPU cores',
#  'RAM size',
#  'operating system',
#  'drive type',
#  'input devices',
#  'multimedia',
#  'RAM type',
#  'CPU clock speed (GHz)',
#  'CPU model',
#  'state',
#  'drive memory size (GB)',
#  'warranty',
#  'screen size',
#  'buynow_price']

# %%
# 'state' column only a single value 'New' will not effect in developing a ML model
# drop state column
df = df.drop(columns='state')
df = df.dropna()
df.columns
# Out:
# Index(['graphic card type', 'communications', 'resolution (px)', 'CPU cores',
#        'RAM size', 'operating system', 'drive type', 'input devices',
#        'multimedia', 'RAM type', 'CPU clock speed (GHz)', 'CPU model',
#        'drive memory size (GB)', 'warranty', 'screen size', 'buynow_price'],
#       dtype='object')

# %%
compact_cols = ['communications', 'input devices', 'multimedia']

# %%
df[compact_cols]
# Out:
#                                 communications  \
# 7233         [bluetooth, lan 10/100/1000 mbps]
# 5845       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897                        [wi-fi, bluetooth]
# 4870       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                                        ...
# 9211  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748              [bluetooth, lan 10/100 mbps]
# 2072  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741              [bluetooth, lan 10/100 mbps]
# 6980              [bluetooth, lan 10/100 mbps]
#
#                                           input devices  \
# 7233  [keyboard, touchpad, illuminated keyboard, num...
# 5845             [keyboard, touchpad, numeric keyboard]
# 5897         [keyboard, touchpad, illuminated keyboard]
# 4870             [keyboard, touchpad, numeric keyboard]
# 2498  [keyboard, touchpad, illuminated keyboard, num...
# ...                                                 ...
# 9211  [keyboard, touchpad, illuminated keyboard, num...
# 2748             [keyboard, touchpad, numeric keyboard]
# 2072  [keyboard, touchpad, illuminated keyboard, num...
# 4741         [keyboard, touchpad, illuminated keyboard]
# 6980         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia
# 7233  [SD card reader, camera, speakers, microphone]
# 5845  [SD card reader, camera, speakers, microphone]
# 5897  [SD card reader, camera, speakers, microphone]
# 4870  [SD card reader, camera, speakers, microphone]
# 2498  [SD card reader, camera, speakers, microphone]
# ...                                              ...
# 9211  [SD card reader, camera, speakers, microphone]
# 2748  [SD card reader, camera, speakers, microphone]
# 2072  [SD card reader, camera, speakers, microphone]
# 4741  [SD card reader, camera, speakers, microphone]
# 6980                  [camera, speakers, microphone]
#
# [6109 rows x 3 columns]

# %%
pd.DataFrame(df['input devices'].to_list()).sample(20)
# Out:
#              0         1                     2                 3
# 2443  keyboard  touchpad                  None              None
# 5042  keyboard  touchpad      numeric keyboard              None
# 3104  keyboard  touchpad  illuminated keyboard  numeric keyboard
# 3293  keyboard  touchpad                  None              None
# 2176  keyboard  touchpad  illuminated keyboard  numeric keyboard
# 2054  keyboard  touchpad      numeric keyboard              None
# 3612  keyboard  touchpad  illuminated keyboard  numeric keyboard
# 4573  keyboard  touchpad      numeric keyboard              None
# 2509  keyboard  touchpad                  None              None
# 3836  keyboard  touchpad  illuminated keyboard  numeric keyboard
# 4427  keyboard  touchpad                  None              None
# 4948  keyboard  touchpad                  None              None
# 5177  keyboard  touchpad      numeric keyboard              None
# 4928  keyboard  touchpad                  None              None
# 2667  keyboard  touchpad      numeric keyboard              None
# 728   keyboard  touchpad      numeric keyboard              None
# 2073  keyboard  touchpad      numeric keyboard              None
# 148   keyboard  touchpad                  None              None
# 237   keyboard  touchpad      numeric keyboard              None
# 1407  keyboard  touchpad                  None              None

# %%
df['communications'].to_list()
# Out:
# [['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'gps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'intel wireless display (widi)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'nfc (near field communication)', 'modem 3g (wwan)'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'intel wireless display (widi)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'intel wireless display (widi)'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'intel wireless display (widi)'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'intel wireless display (widi)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['gps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n', 'bluetooth'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'intel wireless display (widi)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['intel wireless display (widi)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['nfc (near field communication)', 'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)', 'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps', 'intel wireless display (widi)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi 802.11 b/g/n', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 a/b/g/n', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100/1000 mbps', 'nfc (near field communication)', 'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'intel wireless display (widi)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'intel wireless display (widi)'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps', 'intel wireless display (widi)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'intel wireless display (widi)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['nfc (near field communication)'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100/1000 mbps', 'nfc (near field communication)', 'gps'],
#  ['nfc (near field communication)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100/1000 mbps', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi 802.11 b/g/n', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'nfc (near field communication)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'lan 10/100/1000 mbps', 'nfc (near field communication)', 'gps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100/1000 mbps',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi',
#   'bluetooth',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps', 'intel wireless display (widi)'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)'],
#  ['bluetooth'],
#  ['bluetooth'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps', 'intel wireless display (widi)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['lan 10/100 mbps', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)', 'gps'],
#  ['nfc (near field communication)', 'gps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['nfc (near field communication)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'nfc (near field communication)', 'gps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100 mbps'],
#  ['lan 10/100/1000 mbps', 'nfc (near field communication)'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['lan 10/100/1000 mbps', 'nfc (near field communication)', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps', 'modem 4g (lte)'],
#  ['bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['bluetooth', 'lan 10/100 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['bluetooth'],
#  ['bluetooth'],
#  ['bluetooth',
#   'lan 10/100/1000 mbps',
#   'lan 10/100 mbps',
#   'intel wireless display (widi)',
#   'nfc (near field communication)',
#   'modem 3g (wwan)'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi 802.11 a/b/g/n', 'bluetooth'],
#  ['wi-fi 802.11 a/b/g/n/ac', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ['wi-fi', 'bluetooth', 'lan 10/100/1000 mbps'],
#  ...]

# %%
def get_unique_val(col_name):
    col_df = pd.DataFrame(df[col_name].to_list())
    unique_vals = list()

    for col in col_df.columns.to_list():
        unique_vals += [val for val in list(col_df[col].unique()) if (val not in unique_vals and val is not None)]

    return unique_vals

# %%
get_unique_val('input devices')
get_unique_val('multimedia')
# Out:
# ['SD card reader', 'camera', 'microphone', 'speakers']

# %%
compact_dict = {"communications": get_unique_val('communications'),
 "input devices": get_unique_val('input devices'),
 "multimedia": get_unique_val('multimedia')}

# %%
compact_dict
# Out:
# {'communications': ['bluetooth',
#   'wi-fi',
#   'wi-fi 802.11 b/g/n/ac',
#   'lan 10/100 mbps',
#   'wi-fi 802.11 a/b/g/n/ac',
#   'nfc (near field communication)',
#   'lan 10/100/1000 mbps',
#   'gps',
#   'wi-fi 802.11 b/g/n',
#   'intel wireless display (widi)',
#   'wi-fi 802.11 a/b/g/n',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  'input devices': ['keyboard',
#   'touchpad',
#   'illuminated keyboard',
#   'numeric keyboard'],
#  'multimedia': ['SD card reader', 'camera', 'microphone', 'speakers']}

# %%
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4    32 gb                       [no system]
# 5845      1366 x 768         4     8 gb                 [windows 10 home]
# 5897     2560 x 1440         4     8 gb                 [windows 10 home]
# 4870      1366 x 768         2     8 gb                 [windows 10 home]
# 2498     1920 x 1080         4     8 gb  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4    32 gb                 [windows 10 home]
# 2748      1600 x 900         4     8 gb                 [windows 10 home]
# 2072     1920 x 1080         4     8 gb                       [no system]
# 4741     1920 x 1080         4    12 gb                       [no system]
# 6980     1920 x 1080         4    32 gb                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price
# 7233  producer warranty  17" - 17.9"       4999.00
# 5845    seller warranty  15" - 15.9"       2649.00
# 5897  producer warranty  12" - 12.9"       4499.00
# 4870  producer warranty  15" - 15.9"       2099.00
# 2498  producer warranty  17" - 17.9"       2699.00
# ...                 ...          ...           ...
# 9211  producer warranty  15" - 15.9"       5599.00
# 2748    seller warranty  17" - 17.9"       2925.36
# 2072  producer warranty  17" - 17.9"       3799.00
# 4741  producer warranty  15" - 15.9"       5589.00
# 6980  producer warranty  15" - 15.9"       8678.00
#
# [6109 rows x 16 columns]

# %%
df['RAM size'] = df['RAM size'].str.replace(' gb', '', regex=True).astype('int32')
# df['RAM size'] = df['RAM size'].astype('int32')

# %%
df['screen size'] = df['screen size'].apply(lambda x:x.split('"')[0])
df.head()
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
#
#      resolution (px) CPU cores  RAM size                  operating system  \
# 7233     1920 x 1080         4        32                       [no system]
# 5845      1366 x 768         4         8                 [windows 10 home]
# 5897     2560 x 1440         4         8                 [windows 10 home]
# 4870      1366 x 768         2         8                 [windows 10 home]
# 2498     1920 x 1080         4         8  [windows 8.1 home 64-bit, other]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
#
#                warranty screen size  buynow_price
# 7233  producer warranty          17        4999.0
# 5845    seller warranty          15        2649.0
# 5897  producer warranty          12        4499.0
# 4870  producer warranty          15        2099.0
# 2498  producer warranty          17        2699.0

# %%
df['resolution_x'] = df['resolution (px)'].apply(lambda x: int(x.split(' x ')[0]))
df['resolution_y'] = df['resolution (px)'].apply(lambda x: int(x.split(' x ')[1]))
df.drop(columns='resolution (px)', inplace=True)

# %%
df.columns
# Out:
# Index(['graphic card type', 'communications', 'CPU cores', 'RAM size',
#        'operating system', 'drive type', 'input devices', 'multimedia',
#        'RAM type', 'CPU clock speed (GHz)', 'CPU model',
#        'drive memory size (GB)', 'warranty', 'screen size', 'buynow_price',
#        'resolution_x', 'resolution_y'],
#       dtype='object')

# %%
df.head(1)
# Out:
#        graphic card type                     communications CPU cores  \
# 7233  dedicated graphics  [bluetooth, lan 10/100/1000 mbps]         4
#
#       RAM size operating system drive type  \
# 7233        32      [no system]  ssd + hdd
#
#                                           input devices  \
# 7233  [keyboard, touchpad, illuminated keyboard, num...
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
#
#                warranty screen size  buynow_price  resolution_x  resolution_y
# 7233  producer warranty          17        4999.0          1920          1080

# %%
numerical_cols = [ 'CPU cores', 'RAM size', 'CPU clock speed (GHz)', 'drive memory size (GB)',
                     'screen size', 'resolution_x', 'resolution_y']
numerical_df = df[numerical_cols].astype(float)
numerical_df.head()
# Out:
#       CPU cores  RAM size  CPU clock speed (GHz)  drive memory size (GB)  \
# 7233        4.0      32.0                    2.6                  1250.0
# 5845        4.0       8.0                    2.4                   256.0
# 5897        4.0       8.0                    1.2                   256.0
# 4870        2.0       8.0                    2.0                  1000.0
# 2498        4.0       8.0                    2.4                  1000.0
#
#       screen size  resolution_x  resolution_y
# 7233         17.0        1920.0        1080.0
# 5845         15.0        1366.0         768.0
# 5897         12.0        2560.0        1440.0
# 4870         15.0        1366.0         768.0
# 2498         17.0        1920.0        1080.0

# %% [markdown]
# ### one hot encoding

# %%
dummies_df = df['operating system'].str.join('|').str.get_dummies()

# %%
df.head(5)
# Out:
#         graphic card type                            communications CPU cores  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]         4
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]         4
# 5897  integrated graphics                        [wi-fi, bluetooth]         4
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]         2
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]         4
#
#       RAM size                  operating system drive type  \
# 7233        32                       [no system]  ssd + hdd
# 5845         8                 [windows 10 home]        ssd
# 5897         8                 [windows 10 home]        ssd
# 4870         8                 [windows 10 home]        hdd
# 2498         8  [windows 8.1 home 64-bit, other]        hdd
#
#                                           input devices  \
# 7233  [keyboard, touchpad, illuminated keyboard, num...
# 5845             [keyboard, touchpad, numeric keyboard]
# 5897         [keyboard, touchpad, illuminated keyboard]
# 4870             [keyboard, touchpad, numeric keyboard]
# 2498  [keyboard, touchpad, illuminated keyboard, num...
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
#
#                warranty screen size  buynow_price  resolution_x  resolution_y
# 7233  producer warranty          17        4999.0          1920          1080
# 5845    seller warranty          15        2649.0          1366           768
# 5897  producer warranty          12        4499.0          2560          1440
# 4870  producer warranty          15        2099.0          1366           768
# 2498  producer warranty          17        2699.0          1920          1080

# %%
dummy_cols = ['drive type', 'RAM type', 'CPU model']
for col in dummy_cols:
    col_dummies_df = df[col].str.get_dummies()
    dummies_df = pd.concat([dummies_df, col_dummies_df], axis=1)

dummies_df
# Out:
#       no system  other  windows 10 home  windows 10 professional  \
# 7233          1      0                0                        0
# 5845          0      0                1                        0
# 5897          0      0                1                        0
# 4870          0      0                1                        0
# 2498          0      1                0                        0
# ...         ...    ...              ...                      ...
# 9211          0      0                1                        0
# 2748          0      0                1                        0
# 2072          1      0                0                        0
# 4741          1      0                0                        0
# 6980          0      0                1                        0
#
#       windows 7 home 64-bit  windows 7 professional 32-bit  \
# 7233                      0                              0
# 5845                      0                              0
# 5897                      0                              0
# 4870                      0                              0
# 2498                      0                              0
# ...                     ...                            ...
# 9211                      0                              0
# 2748                      0                              0
# 2072                      0                              0
# 4741                      0                              0
# 6980                      0                              0
#
#       windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 7233                              0                        0
# 5845                              0                        0
# 5897                              0                        0
# 4870                              0                        0
# 2498                              0                        0
# ...                             ...                      ...
# 9211                              0                        0
# 2748                              0                        0
# 2072                              0                        0
# 4741                              0                        0
# 6980                              0                        0
#
#       windows 8.1 home 64-bit  windows 8.1 professional 32-bit  ...  \
# 7233                        0                                0  ...
# 5845                        0                                0  ...
# 5897                        0                                0  ...
# 4870                        0                                0  ...
# 2498                        1                                0  ...
# ...                       ...                              ...  ...
# 9211                        0                                0  ...
# 2748                        0                                0  ...
# 2072                        0                                0  ...
# 4741                        0                                0  ...
# 6980                        0                                0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                        0                0                         0
# 5845                        0                0                         0
# 5897                        0                0                         0
# 4870                        0                0                         0
# 2498                        0                0                         0
# ...                       ...              ...                       ...
# 9211                        0                0                         0
# 2748                        0                0                         0
# 2072                        0                0                         0
# 4741                        0                0                         0
# 6980                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 7233              0              0              1             0
# 5845              0              0              1             0
# 5897              0              0              0             0
# 4870              1              0              0             0
# 2498              0              0              1             0
# ...             ...            ...            ...           ...
# 9211              0              0              1             0
# 2748              0              0              1             0
# 2072              0              0              1             0
# 4741              0              0              1             0
# 6980              0              0              1             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                        0                         0          0
# 5845                        0                         0          0
# 5897                        0                         0          1
# 4870                        0                         0          0
# 2498                        0                         0          0
# ...                       ...                       ...        ...
# 9211                        0                         0          0
# 2748                        0                         0          0
# 2072                        0                         0          0
# 4741                        0                         0          0
# 6980                        0                         0          0
#
# [6109 rows x 36 columns]

# %%
# check remaining columns
label_col = ['buynow_price']
categorical_columns = [col for col in df.columns.to_list() if col not in compact_cols + label_col + numerical_cols + ['operating system'] + dummy_cols]
categorical_columns
# Out:
# ['graphic card type', 'warranty']

# %%
# encode them
categorical_df = pd.get_dummies(df[categorical_columns])
categorical_df
# Out:
#       graphic card type_dedicated graphics  \
# 7233                                     1
# 5845                                     1
# 5897                                     0
# 4870                                     0
# 2498                                     1
# ...                                    ...
# 9211                                     1
# 2748                                     1
# 2072                                     1
# 4741                                     1
# 6980                                     1
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                      0                           1
# 5845                                      0                           0
# 5897                                      1                           1
# 4870                                      1                           1
# 2498                                      0                           1
# ...                                     ...                         ...
# 9211                                      0                           1
# 2748                                      0                           0
# 2072                                      0                           1
# 4741                                      0                           1
# 6980                                      0                           1
#
#       warranty_seller warranty
# 7233                         0
# 5845                         1
# 5897                         0
# 4870                         0
# 2498                         0
# ...                        ...
# 9211                         0
# 2748                         1
# 2072                         0
# 4741                         0
# 6980                         0
#
# [6109 rows x 4 columns]

# %%
# put unique_vals to compact_df columns
unique_cols = list()
for col in compact_cols:
    unique_cols += compact_dict[col]
compact_df = pd.DataFrame(columns = unique_cols , index=df.index, data=np.zeros((df.shape[0], len(unique_cols))))
compact_df
# Out:
#       bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  lan 10/100 mbps  \
# 7233        0.0    0.0                    0.0              0.0
# 5845        0.0    0.0                    0.0              0.0
# 5897        0.0    0.0                    0.0              0.0
# 4870        0.0    0.0                    0.0              0.0
# 2498        0.0    0.0                    0.0              0.0
# ...         ...    ...                    ...              ...
# 9211        0.0    0.0                    0.0              0.0
# 2748        0.0    0.0                    0.0              0.0
# 2072        0.0    0.0                    0.0              0.0
# 4741        0.0    0.0                    0.0              0.0
# 6980        0.0    0.0                    0.0              0.0
#
#       wi-fi 802.11 a/b/g/n/ac  nfc (near field communication)  \
# 7233                      0.0                             0.0
# 5845                      0.0                             0.0
# 5897                      0.0                             0.0
# 4870                      0.0                             0.0
# 2498                      0.0                             0.0
# ...                       ...                             ...
# 9211                      0.0                             0.0
# 2748                      0.0                             0.0
# 2072                      0.0                             0.0
# 4741                      0.0                             0.0
# 6980                      0.0                             0.0
#
#       lan 10/100/1000 mbps  gps  wi-fi 802.11 b/g/n  \
# 7233                   0.0  0.0                 0.0
# 5845                   0.0  0.0                 0.0
# 5897                   0.0  0.0                 0.0
# 4870                   0.0  0.0                 0.0
# 2498                   0.0  0.0                 0.0
# ...                    ...  ...                 ...
# 9211                   0.0  0.0                 0.0
# 2748                   0.0  0.0                 0.0
# 2072                   0.0  0.0                 0.0
# 4741                   0.0  0.0                 0.0
# 6980                   0.0  0.0                 0.0
#
#       intel wireless display (widi)  ...  modem 3g (wwan)  modem 4g (lte)  \
# 7233                            0.0  ...              0.0             0.0
# 5845                            0.0  ...              0.0             0.0
# 5897                            0.0  ...              0.0             0.0
# 4870                            0.0  ...              0.0             0.0
# 2498                            0.0  ...              0.0             0.0
# ...                             ...  ...              ...             ...
# 9211                            0.0  ...              0.0             0.0
# 2748                            0.0  ...              0.0             0.0
# 2072                            0.0  ...              0.0             0.0
# 4741                            0.0  ...              0.0             0.0
# 6980                            0.0  ...              0.0             0.0
#
#       keyboard  touchpad  illuminated keyboard  numeric keyboard  \
# 7233       0.0       0.0                   0.0               0.0
# 5845       0.0       0.0                   0.0               0.0
# 5897       0.0       0.0                   0.0               0.0
# 4870       0.0       0.0                   0.0               0.0
# 2498       0.0       0.0                   0.0               0.0
# ...        ...       ...                   ...               ...
# 9211       0.0       0.0                   0.0               0.0
# 2748       0.0       0.0                   0.0               0.0
# 2072       0.0       0.0                   0.0               0.0
# 4741       0.0       0.0                   0.0               0.0
# 6980       0.0       0.0                   0.0               0.0
#
#       SD card reader  camera  microphone  speakers
# 7233             0.0     0.0         0.0       0.0
# 5845             0.0     0.0         0.0       0.0
# 5897             0.0     0.0         0.0       0.0
# 4870             0.0     0.0         0.0       0.0
# 2498             0.0     0.0         0.0       0.0
# ...              ...     ...         ...       ...
# 9211             0.0     0.0         0.0       0.0
# 2748             0.0     0.0         0.0       0.0
# 2072             0.0     0.0         0.0       0.0
# 4741             0.0     0.0         0.0       0.0
# 6980             0.0     0.0         0.0       0.0
#
# [6109 rows x 21 columns]

# %%
# get the values of compact_df from original dataframe
# If the computer includes the column name as a feature assign 1, otherwise 0
for col, unique_list in compact_dict.items():
    for unique in unique_list:
        compact_df[unique] = df[col].apply(lambda x: 1 if unique in x else 0)

compact_df
# Out:
#       bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  lan 10/100 mbps  \
# 7233          1      0                      0                0
# 5845          1      1                      0                1
# 5897          1      1                      0                0
# 4870          1      1                      0                1
# 2498          1      1                      0                0
# ...         ...    ...                    ...              ...
# 9211          1      1                      0                0
# 2748          1      0                      0                1
# 2072          1      1                      0                0
# 4741          1      0                      0                1
# 6980          1      0                      0                1
#
#       wi-fi 802.11 a/b/g/n/ac  nfc (near field communication)  \
# 7233                        0                               0
# 5845                        0                               0
# 5897                        0                               0
# 4870                        0                               0
# 2498                        0                               0
# ...                       ...                             ...
# 9211                        0                               0
# 2748                        0                               0
# 2072                        0                               0
# 4741                        0                               0
# 6980                        0                               0
#
#       lan 10/100/1000 mbps  gps  wi-fi 802.11 b/g/n  \
# 7233                     1    0                   0
# 5845                     0    0                   0
# 5897                     0    0                   0
# 4870                     0    0                   0
# 2498                     1    0                   0
# ...                    ...  ...                 ...
# 9211                     1    0                   0
# 2748                     0    0                   0
# 2072                     1    0                   0
# 4741                     0    0                   0
# 6980                     0    0                   0
#
#       intel wireless display (widi)  ...  modem 3g (wwan)  modem 4g (lte)  \
# 7233                              0  ...                0               0
# 5845                              0  ...                0               0
# 5897                              0  ...                0               0
# 4870                              0  ...                0               0
# 2498                              0  ...                0               0
# ...                             ...  ...              ...             ...
# 9211                              0  ...                0               0
# 2748                              0  ...                0               0
# 2072                              0  ...                0               0
# 4741                              0  ...                0               0
# 6980                              0  ...                0               0
#
#       keyboard  touchpad  illuminated keyboard  numeric keyboard  \
# 7233         1         1                     1                 1
# 5845         1         1                     0                 1
# 5897         1         1                     1                 0
# 4870         1         1                     0                 1
# 2498         1         1                     1                 1
# ...        ...       ...                   ...               ...
# 9211         1         1                     1                 1
# 2748         1         1                     0                 1
# 2072         1         1                     1                 1
# 4741         1         1                     1                 0
# 6980         1         1                     1                 0
#
#       SD card reader  camera  microphone  speakers
# 7233               1       1           1         1
# 5845               1       1           1         1
# 5897               1       1           1         1
# 4870               1       1           1         1
# 2498               1       1           1         1
# ...              ...     ...         ...       ...
# 9211               1       1           1         1
# 2748               1       1           1         1
# 2072               1       1           1         1
# 4741               1       1           1         1
# 6980               0       1           1         1
#
# [6109 rows x 21 columns]

# %%
# concatenate all processed dataframe to put together
new_df = pd.concat([categorical_df, numerical_df, compact_df, dummies_df],axis=1)
new_df.head(5)
# Out:
#       graphic card type_dedicated graphics  \
# 7233                                     1
# 5845                                     1
# 5897                                     0
# 4870                                     0
# 2498                                     1
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                      0                           1
# 5845                                      0                           0
# 5897                                      1                           1
# 4870                                      1                           1
# 2498                                      0                           1
#
#       warranty_seller warranty  CPU cores  RAM size  CPU clock speed (GHz)  \
# 7233                         0        4.0      32.0                    2.6
# 5845                         1        4.0       8.0                    2.4
# 5897                         0        4.0       8.0                    1.2
# 4870                         0        2.0       8.0                    2.0
# 2498                         0        4.0       8.0                    2.4
#
#       drive memory size (GB)  screen size  resolution_x  ...  \
# 7233                  1250.0         17.0        1920.0  ...
# 5845                   256.0         15.0        1366.0  ...
# 5897                   256.0         12.0        2560.0  ...
# 4870                  1000.0         15.0        1366.0  ...
# 2498                  1000.0         17.0        1920.0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                        0                0                         0
# 5845                        0                0                         0
# 5897                        0                0                         0
# 4870                        0                0                         0
# 2498                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 7233              0              0              1             0
# 5845              0              0              1             0
# 5897              0              0              0             0
# 4870              1              0              0             0
# 2498              0              0              1             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                        0                         0          0
# 5845                        0                         0          0
# 5897                        0                         0          1
# 4870                        0                         0          0
# 2498                        0                         0          0
#
# [5 rows x 68 columns]

# %%
new_df.shape
# Out:
# (6109, 68)

# %% [markdown]
# ## Multicollinearity Check
# Multicollinearity is a potential problem for this regression task. We will check it through `Variance Inflation Factor (VIF)`. We will eliminate all features that have `VIF` score above 20. For each iteration, we will drop only one feature, since when the feature set is changed `VIF` scores also change.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# compute VIF score with variance_inflation_factor() function
def compute_vif(features):
    vif_data = pd.DataFrame()
    vif_data["feature"] = features
    vif_data["VIF"] = [variance_inflation_factor(new_df[features].values, i) for i in range(len(features))]
    return vif_data.sort_values(by=['VIF']).reset_index(drop=True)

# %%
# %timeit
# apply VIF computation to all columns
features = new_df.columns.to_list()
vif_data = compute_vif(features)
vif_data
# Out:
#                                   feature       VIF
# 0                   windows 7 home 64-bit  1.027793
# 1         windows 8.1 professional 32-bit  1.032288
# 2           windows 7 professional 32-bit  1.038891
# 3                    wi-fi 802.11 a/b/g/n  1.074400
# 4                 wi-fi 802.11 a/b/g/n/ac  1.120884
# ..                                    ...       ...
# 63               warranty_seller warranty       inf
# 64             warranty_producer warranty       inf
# 65  graphic card type_integrated graphics       inf
# 66                                amd a12       inf
# 67                              other CPU       inf
#
# [68 rows x 2 columns]

# %%
# drop with highest vif score until all vif scores are under 20
multicollinearity = True

while multicollinearity:
    highest_vif_feature = vif_data['feature'].values.tolist()[-1]
    print("I will remove: ", highest_vif_feature)
    features.remove(highest_vif_feature)
    vif_data = compute_vif(features)
    multicollinearity = False if len(vif_data[vif_data.VIF > 20]) == 0 else True

selected_features = vif_data['feature'].values.tolist()
vif_data
# Out:
# I will remove:  other CPU
# I will remove:  graphic card type_dedicated graphics
# I will remove:  ssd
# I will remove:  ddr3
# I will remove:  warranty_producer warranty
# I will remove:  resolution_x
# I will remove:  touchpad
# I will remove:  screen size
# I will remove:  camera
# I will remove:  CPU clock speed (GHz)
# I will remove:  windows 10 home
# I will remove:  keyboard
# I will remove:  intel core i7
# I will remove:  bluetooth
# I will remove:  CPU cores
# I will remove:  microphone
#                                   feature        VIF
# 0         windows 8.1 professional 32-bit   1.004397
# 1                   windows 7 home 64-bit   1.007451
# 2                         intel celeron m   1.019598
# 3           windows 7 professional 32-bit   1.022183
# 4                 windows 8.1 home 32-bit   1.028446
# 5                            intel core m   1.030207
# 6                                  amd a4   1.036642
# 7                                  amd e1   1.043705
# 8                                 amd a10   1.046219
# 9                                 amd a12   1.069440
# 10                                 amd a8   1.071880
# 11                   wi-fi 802.11 a/b/g/n   1.073022
# 12        windows 8.1 professional 64-bit   1.077931
# 13                                 hybrid   1.103788
# 14                     wi-fi 802.11 b/g/n   1.110669
# 15               intel celeron quad core    1.116365
# 16                wi-fi 802.11 a/b/g/n/ac   1.131450
# 17                  wi-fi 802.11 b/g/n/ac   1.141680
# 18               intel pentium quad-core    1.149561
# 19                         intel celeron    1.204518
# 20                                   emmc   1.221507
# 21                windows 8.1 home 64-bit   1.235370
# 22                                 amd a6   1.294658
# 23                intel celeron dual-core   1.322774
# 24          windows 7 professional 64-bit   1.374842
# 25                intel pentium dual-core   1.462701
# 26                              no system   1.624144
# 27                                  other   1.670733
# 28                                  ddr3l   1.762495
# 29                         modem 4g (lte)   1.816467
# 30                windows 10 professional   1.826081
# 31                                    gps   2.055969
# 32                          intel core i5   2.371960
# 33               warranty_seller warranty   2.450624
# 34                          intel core i3   2.602559
# 35  graphic card type_integrated graphics   2.816756
# 36                                    hdd   3.073258
# 37                              ssd + hdd   3.339705
# 38                                  wi-fi   3.650341
# 39                   illuminated keyboard   3.912885
# 40                        lan 10/100 mbps   4.133288
# 41                       numeric keyboard   4.481229
# 42                               RAM size   4.581111
# 43                        modem 3g (wwan)   4.634074
# 44          intel wireless display (widi)   4.812889
# 45         nfc (near field communication)   6.033135
# 46                   lan 10/100/1000 mbps   6.522752
# 47                 drive memory size (GB)   8.793418
# 48                                   ddr4   9.649817
# 49                         SD card reader  13.357129
# 50                               speakers  15.456084
# 51                           resolution_y  18.780724

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# correlation matrix of multicollinearity free dataset
plt.figure(figsize=(20, 20)) # width and height in inches
corr_df = pd.concat([new_df[selected_features], df[label_col]], axis=1)
sns.heatmap(corr_df.corr(),annot=True, lw=1)
plt.show()

# %% [markdown]
# ## Train/Val/Test Split

# %%
# use the indeces of given datasets to properly separate it again as initial datasets
train_indeces = train_df.dropna().index
val_indeces = val_df.dropna().index
test_indeces = test_df.dropna().index

# %%
train_df = new_df.loc[train_indeces]
val_df = new_df.loc[val_indeces]
test_df = new_df.loc[test_indeces]

# %%
# sklearn machine learning models expect y_train, y_test, y_val
# in the shape as (row_number, ) instead of (row_number, 1) shape, so apply .ravel()
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
X_train.shape
# Out:
# (3694, 52)

# %%
y_train.shape
# Out:
# (3694,)

# %% [markdown]
# ## Classical Machine Learning
# We will implement and try different machine learning models from Linear Regression to Ensemble Methods. We will measure root-mean-squared-error as instructed. We will scale our data with `MaxAbsScaler()` from sklearn, which works well with sparse datasets.

# %%
train_df
# Out:
#        graphic card type_dedicated graphics  \
# 7233                                      1
# 5845                                      1
# 5897                                      0
# 4870                                      0
# 2498                                      1
# ...                                     ...
# 2954                                      0
# 4816                                      0
# 11249                                     0
# 685                                       0
# 2307                                      1
#
#        graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                       0                           1
# 5845                                       0                           0
# 5897                                       1                           1
# 4870                                       1                           1
# 2498                                       0                           1
# ...                                      ...                         ...
# 2954                                       1                           0
# 4816                                       1                           1
# 11249                                      1                           0
# 685                                        1                           1
# 2307                                       0                           1
#
#        warranty_seller warranty  CPU cores  RAM size  CPU clock speed (GHz)  \
# 7233                          0        4.0      32.0                   2.60
# 5845                          1        4.0       8.0                   2.40
# 5897                          0        4.0       8.0                   1.20
# 4870                          0        2.0       8.0                   2.00
# 2498                          0        4.0       8.0                   2.40
# ...                         ...        ...       ...                    ...
# 2954                          1        4.0       6.0                   1.80
# 4816                          0        2.0       8.0                   2.00
# 11249                         1        2.0       4.0                   1.70
# 685                           0        4.0       4.0                   1.86
# 2307                          0        2.0       8.0                   2.30
#
#        drive memory size (GB)  screen size  resolution_x  ...  \
# 7233                   1250.0         17.0        1920.0  ...
# 5845                    256.0         15.0        1366.0  ...
# 5897                    256.0         12.0        2560.0  ...
# 4870                   1000.0         15.0        1366.0  ...
# 2498                   1000.0         17.0        1920.0  ...
# ...                       ...          ...           ...  ...
# 2954                    256.0         15.0        1366.0  ...
# 4816                    480.0         15.0        1920.0  ...
# 11249                   500.0         12.0        1920.0  ...
# 685                    1000.0         17.0        1600.0  ...
# 2307                   1000.0         15.0        1920.0  ...
#
#        intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                         0                0                         0
# 5845                         0                0                         0
# 5897                         0                0                         0
# 4870                         0                0                         0
# 2498                         0                0                         0
# ...                        ...              ...                       ...
# 2954                         0                0                         0
# 4816                         0                0                         0
# 11249                        0                0                         0
# 685                          0                0                         1
# 2307                         0                0                         0
#
#        intel core i3  intel core i5  intel core i7  intel core m  \
# 7233               0              0              1             0
# 5845               0              0              1             0
# 5897               0              0              0             0
# 4870               1              0              0             0
# 2498               0              0              1             0
# ...              ...            ...            ...           ...
# 2954               0              0              0             0
# 4816               1              0              0             0
# 11249              1              0              0             0
# 685                0              0              0             0
# 2307               0              1              0             0
#
#        intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                         0                         0          0
# 5845                         0                         0          0
# 5897                         0                         0          1
# 4870                         0                         0          0
# 2498                         0                         0          0
# ...                        ...                       ...        ...
# 2954                         0                         0          0
# 4816                         0                         0          0
# 11249                        0                         0          0
# 685                          0                         0          0
# 2307                         0                         0          0
#
# [3694 rows x 68 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import VotingRegressor
from sklearn import linear_model
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns

# %% [markdown]
# # Default models

# %%
def rmse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred, squared=False)


def regression(regressor_name, regressor):
#     alternative scaler
#     pipe = make_pipeline(StandardScaler(), regressor)
    pipe = make_pipeline(MaxAbsScaler(), regressor)
    pipe.fit(X_train, y_train)
    predicted = pipe.predict(X_test)
    rmse_val = rmse(y_test, predicted)
    print(regressor_name, ':', rmse_val)
    pred_df[regressor_name+'_Pred'] = predicted
    plt.figure(regressor_name)
    plt.title(regressor_name)
    plt.xlabel('predicted')
    plt.ylabel('actual')
    sns.regplot(y=y_test,x=predicted)

regressors = {
    'Linear' : LinearRegression(),
    'MLP': MLPRegressor(random_state=42, max_iter=500, learning_rate="constant", learning_rate_init=0.6),
    'DecisionTree': DecisionTreeRegressor(max_depth=15, random_state=42),
    'RandomForest': RandomForestRegressor(random_state=42),
    'GradientBoosting': GradientBoostingRegressor(random_state=42, criterion='squared_error',
                                                  loss='squared_error',learning_rate=0.6, warm_start=True),
    'ExtraTrees': ExtraTreesRegressor(n_estimators=100, random_state=42),
}

pred_df = pd.DataFrame(columns =["Actual"])
pred_df["Actual"] = y_test

for key in regressors.keys():
    regression(key, regressors[key])
# Out:
# Linear : 64038581464238.25
# MLP : 719.6561002119159
# DecisionTree : 656.6811883268169
# RandomForest : 557.0123635130183
# GradientBoosting : 526.9818640941238
# ExtraTrees : 577.5740215020353

# %% [markdown]
# **MLP**

# %%
def rmse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred, squared=False)

# %%
# Define the parameter grid
param_grid = {
    'max_iter': [100, 500, 1000],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'learning_rate_init': [0.001, 0.01, 0.1]
}

# Create the estimator and grid search object
estimator = MLPRegressor(random_state=42)
grid_search = GridSearchCV(estimator=estimator, param_grid=param_grid)

# Create the pipeline
pipe = make_pipeline(MaxAbsScaler(), grid_search)

# Fit the pipeline with training data
pipe.fit(X_train, y_train)

# Get the best parameters found by the grid search
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'learning_rate': 'constant', 'learning_rate_init': 0.1, 'max_iter': 500}

# %% [markdown]
# **Decision Tree**

# %%
# Define the parameter grid
param_grid = {
    'max_depth': [10, 30, 60],
    'min_samples_split': [2, 4, 8],
    'min_samples_leaf': [3, 8, 1]
}

# Create the estimator and grid search object
estimator = DecisionTreeRegressor(random_state=42)
grid_search = GridSearchCV(estimator=estimator, param_grid=param_grid)


# Create the pipeline
pipe = make_pipeline(MaxAbsScaler(), grid_search)

# Fit the pipeline with training data
pipe.fit(X_train, y_train)

# Get the best parameters found by the grid search
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}

# %% [markdown]
# **Random Forest**

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [10, 100, 200],
    'max_depth': [10, 50, 100],
    'min_samples_split': [2, 4, 8]
}

# Create the estimator and grid search object
estimator = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(estimator=estimator, param_grid=param_grid)

# Create the pipeline
pipe = make_pipeline(MaxAbsScaler(), grid_search)

# Fit the pipeline with training data
pipe.fit(X_train, y_train)

# Get the best parameters found by the grid search
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'max_depth': 50, 'min_samples_split': 2, 'n_estimators': 200}

# %% [markdown]
# **Gradient Boosting**

# %%
# Define the parameter grid
param_grid = {
    'max_depth': [10, 50, 100],
    'learning_rate': [0.1, 0.01],
    'n_estimators': [50, 100, 200]
}


# Create the estimator and grid search object
estimator = GradientBoostingRegressor(random_state=42)
grid_search = GridSearchCV(estimator=estimator, param_grid=param_grid)

# Create the pipeline
pipe = make_pipeline(MaxAbsScaler(), grid_search)

# Fit the pipeline with training data
pipe.fit(X_train, y_train)

# Get the best parameters found by the grid search
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}

# %% [markdown]
# **Extra Trees**

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [10, 50, 100, 200, 500]
}

# Create the estimator and grid search object
estimator = ExtraTreesRegressor(random_state=42)
grid_search = GridSearchCV(estimator=estimator, param_grid=param_grid)

# Create the pipeline
pipe = make_pipeline(MaxAbsScaler(), grid_search)

# Fit the pipeline with training data
pipe.fit(X_train, y_train)

# Get the best parameters found by the grid search
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'n_estimators': 500}

# %% [markdown]
# # Test for validation_dataset

# %%
# Test for validation data
def regression_val(regressor_name, regressor):
    pipe = make_pipeline(MaxAbsScaler(), regressor)
    pipe.fit(X_train, y_train)
    predicted = pipe.predict(X_val)
    rmse_val = rmse(y_val, predicted)
    print(regressor_name, ':', rmse_val)
    pred_df[regressor_name+'_Pred'] = predicted
    plt.figure(regressor_name)
    plt.title(regressor_name)
    plt.xlabel('predicted')
    plt.ylabel('actual')
    sns.regplot(y=y_val,x=predicted)

# %%
regressors = {
    'MLP': MLPRegressor(random_state=42, max_iter=500, learning_rate="constant", learning_rate_init=0.1),
    'DecisionTree': DecisionTreeRegressor(max_depth=30, random_state=42, min_samples_leaf= 1, min_samples_split= 4),
    'RandomForest': RandomForestRegressor(random_state=42, max_depth = 50, min_samples_split= 2, n_estimators= 200),
    'GradientBoosting': GradientBoostingRegressor(random_state=42, learning_rate =0.1, max_depth= 10, n_estimators= 100, warm_start=True),
    'ExtraTrees': ExtraTreesRegressor(n_estimators=500, random_state=42),
}

pred_df = pd.DataFrame(columns =["Actual"])
pred_df["Actual"] = y_val

for key in regressors.keys():
    regression_val(key, regressors[key])
# Out:
# MLP : 573.8476593587146
# DecisionTree : 632.0714704682384
# RandomForest : 505.80087308402915
# GradientBoosting : 488.90164281570355
# ExtraTrees : 559.1898302384323

# %% [markdown]
# # Test for test_dataset

# %%
def regression_test(regressor_name, regressor):
    pipe = make_pipeline(MaxAbsScaler(), regressor)
    pipe.fit(X_train, y_train)
    predicted = pipe.predict(X_test)
    rmse_val = rmse(y_test, predicted)
    print(regressor_name, ':', rmse_val)
    pred_df[regressor_name+'_Pred'] = predicted
    plt.figure(regressor_name)
    plt.title(regressor_name)
    plt.xlabel('predicted')
    plt.ylabel('actual')
    sns.regplot(y=y_test,x=predicted)

# %%
regressors = {
    'MLP': MLPRegressor(random_state=42, max_iter=500, learning_rate="constant", learning_rate_init=0.1),
    'DecisionTree': DecisionTreeRegressor(max_depth=30, random_state=42, min_samples_leaf= 1, min_samples_split= 4),
    'RandomForest': RandomForestRegressor(random_state=42, max_depth = 50, min_samples_split= 2, n_estimators= 200),
    'GradientBoosting': GradientBoostingRegressor(random_state=42, learning_rate =0.1, max_depth= 10, n_estimators= 100, warm_start=True),
    'ExtraTrees': ExtraTreesRegressor(n_estimators=500, random_state=42),
}

pred_df = pd.DataFrame(columns =["Actual"])
pred_df["Actual"] = y_test

for key in regressors.keys():
    regression_test(key, regressors[key])


# Default model's result

# MLP : 719.6561002119159
# DecisionTree : 656.6811883268169
# RandomForest : 557.0123635130183
# GradientBoosting : 526.9818640941238
# ExtraTrees : 577.5740215020353
# Out:
# MLP : 745.3238397993671
# DecisionTree : 643.7924713933622
# RandomForest : 560.3389825527863
# GradientBoosting : 523.6442349317779
# ExtraTrees : 576.7418089070815

# %%
from sklearn.ensemble import VotingRegressor

# classifiers
reg1 = regressors["GradientBoosting"]
reg2 = regressors["ExtraTrees"]
reg3 = regressors["RandomForest"]

# take the highest performed three models and combine them in a voting mechanism
# assign weights to their predictions and create new regressor
# it is possible to try with different weights
regression_test("Voting", VotingRegressor([("gb", reg1), ("et", reg2), ("rf", reg3)], weights=[0.4, 0.35, 0.25]))
# Out:
# Voting : 532.7701979280059

# %%
pred_df
# Out:
#        Actual     MLP_Pred  DecisionTree_Pred  RandomForest_Pred  \
# 0     2369.00  2203.157692        2369.000000        2312.000000
# 1     2299.00  2349.578435        2395.666667        2294.250000
# 2     5999.00  5139.443251        4999.000000        5001.950595
# 3     1299.00  1319.329172        1261.500000        1261.469544
# 4     3329.00  7637.668243        5599.000000        6050.722569
# ...       ...          ...                ...                ...
# 1195  5599.00  5696.396435        5674.000000        5676.282738
# 1196  2925.36  2729.232547        2928.010000        2892.584230
# 1197  3799.00  4406.187312        4777.000000        4441.894024
# 1198  5589.00  4884.289652        4414.000000        4810.565333
# 1199  8678.00  8023.598274        8144.000000        7948.135000
#
#       GradientBoosting_Pred  ExtraTrees_Pred  Voting_Pred
# 0               2296.718662         2369.000  2325.837465
# 1               2239.375875         2299.000  2273.962850
# 2               5138.431571         4999.000  5055.510277
# 3               1268.813231         1261.500  1264.417678
# 4               5565.381696         5789.900  5765.298321
# ...                     ...              ...          ...
# 1195            5723.343174         5674.000  5694.307954
# 1196            2858.383385         2879.000  2874.149412
# 1197            4005.177479         4216.984  4188.488897
# 1198            5154.507642         4433.782  4816.268090
# 1199            8234.727929         8197.830  8150.165421
#
# [1200 rows x 7 columns]

# %% [markdown]
# It improves the performance of the RandomForest. We can go ahead with this voting model as our official solution.

# %% [markdown]
# ## Feature Selection
# Feature selection hurts the performance of this task. However, it is always best to present all the methods applied through the assignment. Hence, we are representing it also. We used `f_regression` and `RandomForestRegressor.modelimportances` to check feature importance. We decided on `k=25`, but you can change and see the results for different k values.

# %%
from sklearn.feature_selection import SelectKBest, f_regression
#Select top 25 features based on f-regression
selector = SelectKBest(f_regression, k =25)
X = new_df[selected_features].to_numpy()
y = df[label_col].to_numpy().ravel()
selector.fit(X, y)
cols = new_df[selected_features].columns[selector.get_support()].to_list()
cols
# Out:
# ['intel celeron ',
#  'emmc',
#  'amd a6',
#  'intel celeron dual-core',
#  'intel pentium dual-core',
#  'no system',
#  'ddr3l',
#  'modem 4g (lte)',
#  'warranty_seller warranty',
#  'intel core i3',
#  'graphic card type_integrated graphics',
#  'hdd',
#  'ssd + hdd',
#  'wi-fi',
#  'illuminated keyboard',
#  'lan 10/100 mbps',
#  'numeric keyboard',
#  'RAM size',
#  'modem 3g (wwan)',
#  'intel wireless display (widi)',
#  'nfc (near field communication)',
#  'drive memory size (GB)',
#  'ddr4',
#  'SD card reader',
#  'resolution_y']

# %%
X_train, X_val, X_test = train_df[cols].to_numpy(), val_df[cols].to_numpy(), test_df[cols].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression_test('RandomForest', regressors['RandomForest'])
# Out:
# RandomForest : 689.1656849460707

# %%
X = new_df[selected_features].values
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()
model = RandomForestRegressor(random_state=42)
# fit the model
model.fit(X_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print(f"Feature: {selected_features[i]} , Score: {v}")
# plot feature importance
plt.figure(figsize=(12, 9)) # width and height in inches
plt.bar(selected_features, importance)
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()
# Out:
# Feature: windows 8.1 professional 32-bit , Score: 4.973371134104074e-06
# Feature: windows 7 home 64-bit , Score: 0.0
# Feature: intel celeron m , Score: 3.943939831647907e-05
# Feature: windows 7 professional 32-bit , Score: 0.0
# Feature: windows 8.1 home 32-bit , Score: 5.0467194254702984e-05
# Feature: intel core m , Score: 0.00020479544394336958
# Feature: amd a4 , Score: 0.00023012608983633226
# Feature: amd e1 , Score: 7.565799456190145e-05
# Feature: amd a10 , Score: 0.00019426092177305207
# Feature: amd a12 , Score: 0.00024066812922089715
# Feature: amd a8 , Score: 0.00017034014453873547
# Feature: wi-fi 802.11 a/b/g/n , Score: 0.00022288687987535765
# Feature: windows 8.1 professional 64-bit , Score: 0.001235310470718396
# Feature: hybrid , Score: 0.000499177576732892
# Feature: wi-fi 802.11 b/g/n , Score: 0.0001526397408483957
# Feature: intel celeron quad core  , Score: 7.357701733413615e-05
# Feature: wi-fi 802.11 a/b/g/n/ac , Score: 0.001067458351317804
# Feature: wi-fi 802.11 b/g/n/ac , Score: 0.0005960497894708046
# Feature: intel pentium quad-core  , Score: 0.00019861961301126635
# Feature: intel celeron  , Score: 0.0001107153835441639
# Feature: emmc , Score: 0.0016975040154831417
# Feature: windows 8.1 home 64-bit , Score: 0.001023128955237617
# Feature: amd a6 , Score: 0.000953132518575132
# Feature: intel celeron dual-core , Score: 0.0009764189757121278
# Feature: windows 7 professional 64-bit , Score: 0.001152453944208193
# Feature: intel pentium dual-core , Score: 0.00045796477023635776
# Feature: no system , Score: 0.007054283667091695
# Feature: other , Score: 0.002171330770064608
# Feature: ddr3l , Score: 0.0015785370879545565
# Feature: modem 4g (lte) , Score: 0.005406052832353894
# Feature: windows 10 professional , Score: 0.02972064370245019
# Feature: gps , Score: 0.001788899952026604
# Feature: intel core i5 , Score: 0.028590957820728544
# Feature: warranty_seller warranty , Score: 0.006640914161832229
# Feature: intel core i3 , Score: 0.014629901231821861
# Feature: graphic card type_integrated graphics , Score: 0.01826129047914832
# Feature: hdd , Score: 0.012474205781440966
# Feature: ssd + hdd , Score: 0.003327864775714813
# Feature: wi-fi , Score: 0.008312285526344243
# Feature: illuminated keyboard , Score: 0.4155332867280176
# Feature: lan 10/100 mbps , Score: 0.017212224350573062
# Feature: numeric keyboard , Score: 0.0144788397801249
# Feature: RAM size , Score: 0.0752325179654473
# Feature: modem 3g (wwan) , Score: 0.003924365629054971
# Feature: intel wireless display (widi) , Score: 0.008145884320785035
# Feature: nfc (near field communication) , Score: 0.004878795577503675
# Feature: lan 10/100/1000 mbps , Score: 0.008819549355994558
# Feature: drive memory size (GB) , Score: 0.0531385963771469
# Feature: ddr4 , Score: 0.018231408636365794
# Feature: SD card reader , Score: 0.041507593062580256
# Feature: speakers , Score: 0.0015443065492844962
# Feature: resolution_y , Score: 0.18576769718826366

# %%
feats_w_highest_importance = np.array(selected_features)[importance > 0.02].tolist()
feats_w_highest_importance
# Out:
# ['windows 10 professional',
#  'intel core i5',
#  'illuminated keyboard',
#  'RAM size',
#  'drive memory size (GB)',
#  'SD card reader',
#  'resolution_y']

# %%
X_train, X_val, X_test = train_df[feats_w_highest_importance].to_numpy(), val_df[feats_w_highest_importance].to_numpy(), test_df[feats_w_highest_importance].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression_test('RandomForest', regressors['RandomForest'])
# Out:
# RandomForest : 711.0640304029462

# %% [markdown]
# > <b>Still, the complete feature set provides better results compared to features with the highest importance.</b>
